# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'anarchism', 'a', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    print(embed)
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed, train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Tensor("embedding_lookup:0", shape=(128, 128), dtype=float32, device=/device:CPU:0)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.051971
# Nearest to b: quartier, complement, contours, hopeful, petersburg, centimetres, chani, ncipe,
# Nearest to up: premiere, mondale, portrayed, mcculloch, cr, prisons, frail, rescued,
# Nearest to used: kernel, uscis, abol, helix, nkrumah, valentinus, shuffled, admonished,
# Nearest to six: proclamations, toole, bowdoin, megabyte, nostratic, folktales, jabal, backlight,
# Nearest to s: cruisers, arcane, idol, burlington, dana, lup, ty, traditionalist,
# Nearest to a: duel, nagoya, tangential, replenishment, irrationality, decision, carabiners, lavrenty,
# Nearest to only: whereof, fade, cordilleras, physics, mondo, econometrics, tui, emigrate,
# Nearest to also: nonaggression, removable, brittany, villainous, activision, footing, minimization, africans,
# Nearest to after: roulette, bhaktivedanta, jstor, lumped, scudetto, lifted, kohl, centers,
# Nearest to world: sharman, adapa, dug, conductor, making, hl, palgrave, jules,
# Nearest to four: jstor, decisive, intermixed, failed, swapped, footballer, den, ocs,
# Nearest to of: endures, ramanujan, circumnavigated, rtl, wco, cherry, eu, appointees,
# Nearest to two: proudest, soso, paperbacks, estimated, icebergs, demonstrated, paw, scheduling,
# Nearest to was: ddo, download, bessie, interpretive, electromotive, holidays, cider, spartan,
# Nearest to years: stanford, bubbles, borgir, apparel, jazz, soybean, expansions, analgesics,
# Nearest to more: carney, haul, ghent, motets, christe, lisbon, bracewell, kilda,
# Average loss at step 2000: 4.351918
# Average loss at step 4000: 3.864984
# Average loss at step 6000: 3.793274
# Average loss at step 8000: 3.688373
# Average loss at step 10000: 3.614312
# Nearest to b: d, quartier, pasha, chani, barbarous, nb, complement, captured,
# Nearest to up: mondale, premiere, cr, portrayed, capture, slapped, niue, entertainments,
# Nearest to used: alastair, higham, found, disobey, schlick, kabbalist, lent, sprout,
# Nearest to six: eight, seven, five, four, three, nine, zero, two,
# Nearest to s: his, mr, and, hylas, bacardi, warner, afforded, cta,
# Nearest to a: the, symbolically, carabiners, heteronyms, pledges, reestablished, this, mobilized,
# Nearest to only: physics, zeitung, chicxulub, nimitz, exports, rabba, sensory, compulsion,
# Nearest to also: it, often, sometimes, yet, allen, still, naturally, certificates,
# Nearest to after: bakassi, in, of, jstor, essen, dyslexia, musa, bhaktivedanta,
# Nearest to world: renderings, adapa, futuristic, palgrave, autographs, ecclesiastes, abbots, tractor,
# Nearest to four: three, eight, six, seven, five, two, zero, nine,
# Nearest to of: in, for, after, and, on, between, atlanteans, ramanujan,
# Nearest to two: three, four, five, eight, six, seven, one, nine,
# Nearest to was: is, had, has, were, relevant, by, are, ddo,
# Nearest to years: analgesics, bubbles, apparel, promises, likelihood, nano, manifestations, mona,
# Nearest to more: haul, ghent, counts, carney, gravitating, clothing, misandry, criticised,
# Average loss at step 12000: 3.601607
# Average loss at step 14000: 3.567952
# Average loss at step 16000: 3.403635
# Average loss at step 18000: 3.455185
# Average loss at step 20000: 3.535862
# Nearest to b: d, reintroduce, nb, pasha, basement, reconstructing, bog, st,
# Nearest to up: capture, mondale, cr, usurper, officio, their, profiled, entertainments,
# Nearest to used: found, known, incarcerated, disobey, alastair, higham, considered, christophe,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Nearest to s: alternately, mr, flamethrower, isbn, thracians, myanmar, ipa, awesome,
# Nearest to a: carabiners, symbolically, this, consequentialist, another, the, pavement, zooming,
# Nearest to only: chicxulub, intersex, physics, qur, inhibitory, barclays, nimitz, workmen,
# Nearest to also: often, sometimes, which, still, now, it, who, yet,
# Nearest to after: when, essen, bakassi, from, najibullah, toro, salon, pseudo,
# Nearest to world: palgrave, futuristic, ceremonially, tractor, renderings, adapa, autographs, exacted,
# Nearest to four: six, three, eight, five, seven, two, nine, zero,
# Nearest to of: for, ramanujan, same, pancreas, atlanteans, aspires, holliday, in,
# Nearest to two: three, five, four, six, eight, seven, one, zero,
# Nearest to was: is, has, had, were, became, be, been, when,
# Nearest to years: year, analgesics, mona, manifestations, apparel, death, likelihood, kusanagi,
# Nearest to more: less, most, haul, clothing, gravitating, rather, ghent, higgs,
# Average loss at step 22000: 3.503169
# Average loss at step 24000: 3.485572
# Average loss at step 26000: 3.483934
# Average loss at step 28000: 3.479497
# Average loss at step 30000: 3.504526
# Nearest to b: d, reintroduce, nb, reconstructing, regency, milled, manny, pasha,
# Nearest to up: capture, mondale, out, ashland, place, him, land, profiled,
# Nearest to used: found, known, held, given, incarcerated, disobey, punishes, described,
# Nearest to six: four, eight, five, seven, nine, three, two, zero,
# Nearest to s: his, alternately, plantae, myanmar, coexist, mr, her, whose,
# Nearest to a: nagoya, the, no, any, carabiners, reification, another, snp,
# Nearest to only: normally, courbet, no, faye, chicxulub, fractals, nimitz, isotope,
# Nearest to also: often, still, sometimes, now, which, it, insignia, they,
# Nearest to after: when, before, during, bakassi, took, from, najibullah, essen,
# Nearest to world: tractor, futuristic, palgrave, renderings, ceremonially, vietnam, autographs, adapa,
# Nearest to four: six, five, eight, three, seven, two, nine, zero,
# Nearest to of: ramanujan, in, for, and, hc, including, eisenach, original,
# Nearest to two: four, three, five, one, six, seven, eight, nine,
# Nearest to was: is, had, were, has, became, when, been, being,
# Nearest to years: year, days, mona, manifestations, analgesics, paphos, torr, kusanagi,
# Nearest to more: less, very, most, rather, gravitating, outnumbered, huns, haul,
# Average loss at step 32000: 3.503138
# Average loss at step 34000: 3.493257
# Average loss at step 36000: 3.447545
# Average loss at step 38000: 3.304483
# Average loss at step 40000: 3.427113
# Nearest to b: d, regency, f, reintroduce, r, hi, seng, nb,
# Nearest to up: out, them, place, capture, him, mondale, down, cobe,
# Nearest to used: found, known, given, incarcerated, considered, held, described, regarded,
# Nearest to six: five, four, seven, eight, three, nine, two, zero,
# Nearest to s: his, thracians, afforded, her, casas, isbn, homeschool, auf,
# Nearest to a: another, carabiners, the, consequentialist, symbolically, or, devolved, ccitt,
# Nearest to only: it, no, foe, faye, hit, digitization, yet, normally,
# Nearest to also: often, still, which, now, sometimes, usually, not, insignia,
# Nearest to after: before, when, during, bakassi, najibullah, promiscuity, while, salon,
# Nearest to world: tractor, palgrave, renderings, clockmaker, futuristic, autographs, californian, catalogued,
# Nearest to four: six, eight, three, five, seven, two, nine, zero,
# Nearest to of: ramanujan, in, postel, including, for, same, from, fetishism,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to was: is, became, were, has, had, touted, be, when,
# Nearest to years: days, year, months, manifestations, decades, mona, analgesics, benevolent,
# Nearest to more: less, most, very, rather, gravitating, multiprocessor, clothing, detected,
# Average loss at step 42000: 3.435067
# Average loss at step 44000: 3.448796
# Average loss at step 46000: 3.449774
# Average loss at step 48000: 3.349839
# Average loss at step 50000: 3.385878
# Nearest to b: d, r, regency, f, c, cf, hi, complement,
# Nearest to up: out, them, off, down, cobe, him, marple, filo,
# Nearest to used: known, given, found, considered, referred, described, regarded, incarcerated,
# Nearest to six: eight, four, seven, nine, five, three, two, zero,
# Nearest to s: whose, dalmatian, afforded, thracians, and, casas, ili, stereotyping,
# Nearest to a: another, carabiners, any, the, no, symbolically, nagoya, aberfoyle,
# Nearest to only: fluctuating, scored, no, ips, within, periodically, bangs, isotope,
# Nearest to also: often, now, still, which, sometimes, who, mages, ontological,
# Nearest to after: before, when, during, while, for, bakassi, into, last,
# Nearest to world: clockmaker, tractor, renderings, autographs, futuristic, ceremonially, vietnam, catalogued,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to of: ramanujan, including, and, in, for, assassinating, same, neg,
# Nearest to two: three, four, six, five, seven, nine, one, eight,
# Nearest to was: is, has, were, became, had, be, matchbox, rutger,
# Nearest to years: days, year, months, times, decades, benevolent, period, manifestations,
# Nearest to more: less, most, very, rather, highly, longer, larger, gravitating,
# Average loss at step 52000: 3.431777
# Average loss at step 54000: 3.430606
# Average loss at step 56000: 3.433309
# Average loss at step 58000: 3.394242
# Average loss at step 60000: 3.389215
# Nearest to b: d, c, f, r, regency, cf, h, x,
# Nearest to up: out, off, them, down, him, capture, cobe, place,
# Nearest to used: known, given, considered, found, described, seen, designed, regarded,
# Nearest to six: eight, five, four, seven, nine, three, zero, two,
# Nearest to s: whose, specialise, afforded, toward, otis, casas, stereotyping, homeschool,
# Nearest to a: the, another, any, carabiners, this, zooming, analyte, no,
# Nearest to only: normally, fluctuating, until, scored, judged, still, ips, periodically,
# Nearest to also: now, often, still, sometimes, usually, there, it, mages,
# Nearest to after: before, when, during, following, until, while, from, although,
# Nearest to world: clockmaker, renderings, ceremonially, futuristic, federal, tractor, vietnam, govt,
# Nearest to four: six, five, eight, three, seven, nine, zero, two,
# Nearest to of: for, ramanujan, in, main, same, pantheist, including, zak,
# Nearest to two: three, four, five, one, six, seven, eight, zero,
# Nearest to was: is, had, became, were, has, be, when, becomes,
# Nearest to years: days, months, year, decades, times, hours, benevolent, manifestations,
# Nearest to more: less, very, rather, most, highly, longer, better, larger,
# Average loss at step 62000: 3.239970
# Average loss at step 64000: 3.253993
# Average loss at step 66000: 3.401834
# Average loss at step 68000: 3.395708
# Average loss at step 70000: 3.357700
# Nearest to b: d, f, h, x, c, r, regency, w,
# Nearest to up: off, out, them, down, him, capture, back, place,
# Nearest to used: known, described, regarded, responsible, seen, given, written, found,
# Nearest to six: eight, four, nine, seven, five, three, zero, two,
# Nearest to s: whose, isbn, alternately, your, thracians, ionized, durch, tapu,
# Nearest to a: the, another, quite, consequentialist, reification, symbolically, nagoya, enough,
# Nearest to only: normally, fluctuating, judged, still, ulaanbaatar, periodically, yet, until,
# Nearest to also: now, still, often, which, sometimes, usually, actually, ontological,
# Nearest to after: before, during, when, following, while, despite, najibullah, until,
# Nearest to world: renderings, tractor, vietnam, clockmaker, honouring, adapa, catalogued, alds,
# Nearest to four: six, five, seven, three, eight, two, nine, zero,
# Nearest to of: including, original, pantheist, merodach, and, although, include, in,
# Nearest to two: three, four, five, six, seven, one, zero, eight,
# Nearest to was: is, has, had, became, were, been, when, be,
# Nearest to years: days, months, decades, year, hours, times, weeks, minutes,
# Nearest to more: less, most, very, too, highly, rather, detected, increasingly,
# Average loss at step 72000: 3.375105
# Average loss at step 74000: 3.347558
# Average loss at step 76000: 3.311224
# Average loss at step 78000: 3.348713
# Average loss at step 80000: 3.377327
# Nearest to b: d, c, regency, h, r, f, gunships, complement,
# Nearest to up: out, down, off, them, back, place, capture, him,
# Nearest to used: known, described, given, available, considered, seen, regarded, found,
# Nearest to six: five, four, eight, seven, three, nine, two, zero,
# Nearest to s: alternately, flamethrower, passy, whose, brochure, isbn, latinus, slander,
# Nearest to a: another, carabiners, the, any, ghostly, tte, ebony, rhapsody,
# Nearest to only: judged, postmaster, first, either, normally, periodically, fluctuating, faye,
# Nearest to also: now, still, often, sometimes, actually, which, mwali, generally,
# Nearest to after: before, when, during, despite, following, while, until, from,
# Nearest to world: renderings, tractor, clockmaker, honouring, vietnam, adapa, republic, catalogued,
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Nearest to of: ramanujan, sadat, hc, in, aeroplanes, pers, including, arunachal,
# Nearest to two: three, four, six, five, seven, eight, one, zero,
# Nearest to was: is, became, were, has, had, touted, when, been,
# Nearest to years: days, months, year, decades, times, hours, weeks, minutes,
# Nearest to more: less, very, most, highly, too, rather, detected, longer,
# Average loss at step 82000: 3.407413
# Average loss at step 84000: 3.411398
# Average loss at step 86000: 3.383926
# Average loss at step 88000: 3.351723
# Average loss at step 90000: 3.358303
# Nearest to b: c, regency, d, f, guessing, h, ncipe, dm,
# Nearest to up: out, off, down, them, back, him, place, together,
# Nearest to used: known, given, considered, described, seen, available, designed, referred,
# Nearest to six: eight, seven, five, four, nine, three, two, zero,
# Nearest to s: whose, isbn, his, afforded, lorenz, her, katharine, thracians,
# Nearest to a: another, carabiners, any, nagoya, alsos, lombardo, the, custody,
# Nearest to only: judged, periodically, postmaster, resolution, either, even, verne, no,
# Nearest to also: now, often, still, actually, sometimes, which, generally, not,
# Nearest to after: before, during, when, until, despite, while, following, for,
# Nearest to world: renderings, adapa, compile, vietnam, clockmaker, republic, honouring, genre,
# Nearest to four: five, seven, three, eight, six, two, nine, zero,
# Nearest to of: ramanujan, including, for, tetrahedra, include, in, pers, pantheist,
# Nearest to two: three, four, six, five, seven, eight, one, zero,
# Nearest to was: is, became, were, had, has, be, being, wrote,
# Nearest to years: days, months, decades, year, hours, weeks, minutes, times,
# Nearest to more: less, very, most, rather, faster, highly, increasingly, too,
# Average loss at step 92000: 3.398405
# Average loss at step 94000: 3.247067
# Average loss at step 96000: 3.357417
# Average loss at step 98000: 3.241472
# Average loss at step 100000: 3.355289
# Nearest to b: d, regency, nb, carts, reintroduce, shuttles, kosi, semigroup,
# Nearest to up: out, off, down, them, him, back, place, together,
# Nearest to used: given, described, found, considered, known, designed, referred, held,
# Nearest to six: seven, four, eight, five, nine, two, three, zero,
# Nearest to s: whose, his, my, alan, specialise, the, coexist, pcm,
# Nearest to a: any, another, the, tte, nagoya, carabiners, custody, enough,
# Nearest to only: periodically, postmaster, either, not, resolution, within, even, locus,
# Nearest to also: now, actually, still, often, sometimes, generally, currently, never,
# Nearest to after: before, during, when, despite, without, following, until, while,
# Nearest to world: catalogued, country, renderings, adapa, republic, honouring, compile, veterans,
# Nearest to four: five, six, seven, eight, two, nine, three, zero,
# Nearest to of: including, original, sufism, attest, in, amiable, ramanujan, and,
# Nearest to two: four, five, three, six, seven, eight, nine, one,
# Nearest to was: is, has, became, were, had, be, been, being,
# Nearest to years: days, months, decades, year, hours, weeks, minutes, seconds,
# Nearest to more: less, most, very, rather, faster, extremely, increasingly, smaller,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_continuous_bag_of_batch(batch_size, window):
    global data_index
    batch = np.ndarray(shape=(batch_size, window*2), dtype=np.ndarray)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

    for i in range(batch_size):
        midpoint = data_index + window
        batch[i] = np.array(data[data_index:midpoint] + data[midpoint+1:midpoint+window+1])
        labels[i] = data[midpoint]
        data_index = (data_index + 1) % len(data)
            
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for window_size in [2, 4]:
    data_index = 0
    batch, labels = generate_continuous_bag_of_batch(20, window_size)
    print('\nwith window = %d' % (window_size))
    print('    batch:', [reverse_dictionary[bi] for bi in batch[0]])
    print('    labels:', reverse_dictionary[labels[0][0]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with window = 2
#     batch: ['anarchism', 'originated', 'a', 'term']
#     labels: as
#
# with window = 4
#     batch: ['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used']
#     labels: term

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
window_size = 2
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, window_size*2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    avg_embed =  tf.reduce_mean(embed, 1, keep_dims=False)
    # Compute the softmax loss, using a sample of the negative labels each time.
    soft_loss = tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, avg_embed, train_labels, num_sampled, vocabulary_size)
    loss = tf.reduce_mean(soft_loss)

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_continuous_bag_of_batch(batch_size, window_size)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.543692
# Nearest to five: bot, muay, totleben, hedwig, arbitrage, powerfully, ingolstadt, documents,
# Nearest to these: trypanosomiasis, mouton, antiochus, payload, fog, gateways, lycia, parr,
# Nearest to if: assure, fertilize, embroidered, crackdown, amf, strips, polymerization, coincident,
# Nearest to i: banting, oligarchy, des, unbelievers, jury, schott, wanted, phenotypes,
# Nearest to seven: detract, anglia, resin, jesus, resonate, precinct, highlands, improbable,
# Nearest to who: aznar, stunned, nes, amillennialism, nc, disclaimer, allusion, decimals,
# Nearest to d: blinding, logic, rfcs, esse, godless, opteron, roux, characteristic,
# Nearest to for: faisal, rewarded, biograph, doll, encyclopedias, ares, likened, suspension,
# Nearest to can: cub, haig, inward, continual, auditum, brunel, mckellen, dup,
# Nearest to his: berkshire, distasteful, boka, culp, psychometric, academia, powering, cohabitation,
# Nearest to be: boxer, digraph, betrothed, charming, realm, suede, legislator, desertification,
# Nearest to at: fielding, kai, chevrolet, horizon, decidedly, jared, lexicographic, tricolor,
# Nearest to they: colorful, safety, ordaining, wood, hal, redeemed, constraint, stadiums,
# Nearest to have: careers, sint, anime, aunt, stimulant, macrobiotic, ammunition, mack,
# Nearest to it: dogmas, ocogs, bnls, broadsheet, nach, garrisons, rye, selig,
# Nearest to see: convict, chipmunks, truman, yours, novum, mortally, fethry, bord,
# Average loss at step 2000: 4.116040
# Average loss at step 4000: 3.627426
# Average loss at step 6000: 3.438632
# Average loss at step 8000: 3.330642
# Average loss at step 10000: 3.262213
# Nearest to five: six, three, zero, seven, eight, four, totleben, nine,
# Nearest to these: belonged, unspoiled, several, pyrotechnics, westerns, some, belushi, fog,
# Nearest to if: gimmick, polymerization, still, crackdown, since, remark, hindered, would,
# Nearest to i: des, wanted, martyn, midian, ii, gimmick, rancho, z,
# Nearest to seven: nine, six, eight, four, five, zero, three, sloan,
# Nearest to who: allusion, internalized, amillennialism, atomists, nc, uso, he, fly,
# Nearest to d: b, blinding, writer, esse, characteristic, logic, mendicant, dealers,
# Nearest to for: zorn, lydian, faisal, encyclopedias, shunned, franconian, fatimids, likened,
# Nearest to can: will, may, could, would, should, brunel, inward, restraint,
# Nearest to his: s, their, her, countrymen, the, its, thc, distasteful,
# Nearest to be: digraph, cot, have, deceive, betrothed, tuple, sailors, refer,
# Nearest to at: surmised, from, middle, boost, afar, here, shifted, lewin,
# Nearest to they: we, he, factory, safety, vitality, hampstead, chip, there,
# Nearest to have: has, had, cyrus, were, do, be, xs, splicing,
# Nearest to it: he, this, often, there, airstrip, nationally, polos, she,
# Nearest to see: convict, bord, spiritus, browse, novum, fethry, inferential, mayonnaise,
# Average loss at step 12000: 3.291576
# Average loss at step 14000: 3.276698
# Average loss at step 16000: 3.257754
# Average loss at step 18000: 3.255183
# Average loss at step 20000: 3.141342
# Nearest to five: six, four, eight, three, seven, zero, print, nine,
# Nearest to these: some, several, unspoiled, fog, belonged, whose, pyrotechnics, artistry,
# Nearest to if: though, still, crackdown, gimmick, without, polymerization, generally, convinces,
# Nearest to i: ii, we, des, wanted, dear, darts, midian, bypasses,
# Nearest to seven: six, eight, four, five, nine, three, zero, vii,
# Nearest to who: internalized, he, allusion, atomists, rivest, nc, fly, amillennialism,
# Nearest to d: b, blinding, writer, understands, esse, logic, globular, csx,
# Nearest to for: lydian, fluctuated, legislative, encyclopedias, sharing, shunned, usurpation, franconian,
# Nearest to can: will, may, could, should, would, must, cannot, might,
# Nearest to his: her, their, s, its, countrymen, thc, distasteful, my,
# Nearest to be: digraph, refer, sailors, tuple, was, run, been, catastrophes,
# Nearest to at: surmised, mehrgarh, kai, handshake, lombards, boost, lindbergh, fielding,
# Nearest to they: we, he, hampstead, vitality, you, there, asparagus, safety,
# Nearest to have: has, had, were, cyrus, xs, are, obnoxious, having,
# Nearest to it: he, this, she, there, polos, airstrip, psychometrics, heterosexual,
# Nearest to see: convict, spiritus, browse, bord, novum, radiocarbon, adorned, hermetic,
# Average loss at step 22000: 3.191029
# Average loss at step 24000: 3.206831
# Average loss at step 26000: 3.118947
# Average loss at step 28000: 3.157802
# Average loss at step 30000: 3.138198
# Nearest to five: six, three, four, seven, eight, print, zero, foxes,
# Nearest to these: several, some, other, whose, fog, artistry, unspoiled, pyrotechnics,
# Nearest to if: though, without, since, still, intrigue, censorial, polymerization, where,
# Nearest to i: we, ii, you, bypasses, dear, darts, danmarks, des,
# Nearest to seven: six, eight, four, five, nine, three, zero, vii,
# Nearest to who: internalized, he, rivest, atomists, nc, allusion, amillennialism, hotspur,
# Nearest to d: b, writer, blinding, csx, understands, globular, esse, sailed,
# Nearest to for: lydian, sharing, fluctuated, executes, franconian, crater, rosser, danish,
# Nearest to can: may, will, could, should, would, must, cannot, might,
# Nearest to his: her, their, its, s, my, countrymen, thc, westinghouse,
# Nearest to be: digraph, refer, being, been, was, tuple, garten, were,
# Nearest to at: surmised, mehrgarh, fielding, lombards, kai, perfecting, boost, icann,
# Nearest to they: we, you, he, vitality, there, hampstead, asparagus, cer,
# Nearest to have: has, had, were, having, cyrus, are, xs, lensing,
# Nearest to it: he, this, she, there, baldrick, manson, polos, psychometrics,
# Nearest to see: spiritus, convict, browse, frida, bord, hermetic, radiocarbon, adorned,
# Average loss at step 32000: 3.118070
# Average loss at step 34000: 2.983569
# Average loss at step 36000: 3.078164
# Average loss at step 38000: 3.068627
# Average loss at step 40000: 3.053067
# Nearest to five: four, six, seven, three, eight, zero, nine, print,
# Nearest to these: other, several, some, fog, artistry, whose, those, pyrotechnics,
# Nearest to if: though, since, because, intrigue, prohibitively, then, where, crackdown,
# Nearest to i: ii, we, you, g, z, bypasses, unbelievers, danmarks,
# Nearest to seven: six, eight, five, four, nine, zero, three, vii,
# Nearest to who: he, rivest, internalized, atomists, nc, winnipeg, allusion, hotspur,
# Nearest to d: b, blinding, writer, understands, csx, esse, dealers, montoya,
# Nearest to for: fluctuated, sharing, encyclopedias, resonate, lydian, crater, dioxin, legislative,
# Nearest to can: may, will, could, should, must, cannot, would, might,
# Nearest to his: her, their, its, s, my, countrymen, our, thc,
# Nearest to be: being, been, digraph, refer, was, were, garten, is,
# Nearest to at: surmised, mehrgarh, lombards, kai, fielding, icann, perfecting, eastbound,
# Nearest to they: we, he, you, vitality, there, she, invests, asparagus,
# Nearest to have: has, had, having, were, cyrus, contain, are, lensing,
# Nearest to it: he, she, this, there, polos, baldrick, cusp, ottawa,
# Nearest to see: but, hermetic, frida, browse, radiocarbon, spiritus, convict, ibu,
# Average loss at step 42000: 3.063973
# Average loss at step 44000: 3.095089
# Average loss at step 46000: 3.052727
# Average loss at step 48000: 3.065608
# Average loss at step 50000: 2.982857
# Nearest to five: four, seven, three, six, eight, zero, nine, two,
# Nearest to these: several, other, some, fog, whose, which, artistry, different,
# Nearest to if: though, when, since, then, where, prohibitively, because, intrigue,
# Nearest to i: ii, we, g, you, bypasses, z, unbelievers, dear,
# Nearest to seven: eight, six, five, four, nine, three, zero, vii,
# Nearest to who: rivest, internalized, atomists, he, winnipeg, donny, aargau, nc,
# Nearest to d: b, understands, csx, writer, blinding, dealers, globular, palos,
# Nearest to for: sharing, encyclopedias, kotzebue, resonate, fluctuated, quoting, thorne, originate,
# Nearest to can: may, could, will, must, should, cannot, might, would,
# Nearest to his: her, their, its, s, my, our, countrymen, the,
# Nearest to be: being, been, refer, was, digraph, were, become, run,
# Nearest to at: surmised, mehrgarh, icann, kai, lombards, eastbound, perfecting, fielding,
# Nearest to they: we, you, he, there, vitality, asparagus, she, invests,
# Nearest to have: had, has, having, contain, were, cyrus, include, are,
# Nearest to it: he, she, this, there, polos, nothing, baldrick, psychometrics,
# Nearest to see: spiritus, frida, but, radiocarbon, browse, ibu, volcanoes, adorned,
# Average loss at step 52000: 2.981445
# Average loss at step 54000: 3.009722
# Average loss at step 56000: 3.030994
# Average loss at step 58000: 2.882580
# Average loss at step 60000: 2.952806
# Nearest to five: seven, four, six, three, eight, zero, nine, two,
# Nearest to these: several, other, different, which, some, certain, fog, whose,
# Nearest to if: when, then, though, where, therefore, since, thus, because,
# Nearest to i: we, ii, you, g, pontchartrain, desai, unbelievers, bypasses,
# Nearest to seven: six, eight, five, four, nine, three, zero, vii,
# Nearest to who: he, rivest, internalized, winnipeg, atomists, donny, aargau, constricted,
# Nearest to d: b, csx, dealers, writer, montoya, blinding, understands, globular,
# Nearest to for: resonate, franconian, encyclopedias, sixtus, sharing, legislative, oxidase, collided,
# Nearest to can: may, could, will, must, should, cannot, would, might,
# Nearest to his: her, their, my, its, s, our, countrymen, your,
# Nearest to be: being, been, is, run, refer, digraph, produce, was,
# Nearest to at: mehrgarh, surmised, icann, lombards, kai, perfecting, eastbound, bidder,
# Nearest to they: we, you, he, there, asparagus, vitality, she, invests,
# Nearest to have: has, had, having, contain, were, cyrus, are, require,
# Nearest to it: he, she, this, there, nothing, polos, ide, ottawa,
# Nearest to see: but, frida, spiritus, radiocarbon, injunctions, browse, ibu, volcanoes,
# Average loss at step 62000: 2.994577
# Average loss at step 64000: 2.965895
# Average loss at step 66000: 2.864898
# Average loss at step 68000: 2.879001
# Average loss at step 70000: 2.917818
# Nearest to five: six, four, seven, three, eight, zero, two, nine,
# Nearest to these: several, other, different, certain, those, some, various, which,
# Nearest to if: when, then, though, where, because, since, thus, therefore,
# Nearest to i: we, ii, you, g, di, deacidification, bypasses, whiskey,
# Nearest to seven: eight, six, four, five, three, nine, zero, vii,
# Nearest to who: he, winnipeg, internalized, aargau, rivest, donny, atomists, constricted,
# Nearest to d: b, writer, csx, globular, montoya, dealers, blinding, philosopher,
# Nearest to for: resonate, sixtus, oxidase, consider, fluctuated, auditors, encyclopedias, quoting,
# Nearest to can: may, could, will, must, should, cannot, might, would,
# Nearest to his: her, their, my, its, s, our, your, countrymen,
# Nearest to be: being, been, was, refer, occur, remain, produce, diploid,
# Nearest to at: mehrgarh, surmised, icann, lombards, allocated, perfecting, maintains, eastbound,
# Nearest to they: we, you, he, she, vitality, asparagus, there, invests,
# Nearest to have: has, had, having, contain, require, were, include, are,
# Nearest to it: he, she, this, there, nothing, polos, remey, ide,
# Nearest to see: but, spiritus, known, frida, volcanoes, injunctions, relativistic, ibu,
# Average loss at step 72000: 2.883296
# Average loss at step 74000: 2.927460
# Average loss at step 76000: 2.813216
# Average loss at step 78000: 2.926098
# Average loss at step 80000: 2.951985
# Nearest to five: four, six, seven, three, eight, zero, two, nine,
# Nearest to these: other, several, different, those, certain, fog, which, whose,
# Nearest to if: when, then, though, where, thus, therefore, prohibitively, because,
# Nearest to i: we, ii, you, g, deacidification, di, cantor, whiskey,
# Nearest to seven: eight, six, four, five, nine, three, zero, vii,
# Nearest to who: he, winnipeg, rivest, donny, internalized, atomists, aargau, constricted,
# Nearest to d: b, csx, montoya, dealers, understands, globular, writer, godless,
# Nearest to for: franconian, sharing, auditors, payments, aulus, fluctuated, encyclopedias, hashish,
# Nearest to can: may, could, will, must, cannot, should, might, would,
# Nearest to his: her, their, my, its, s, our, your, countrymen,
# Nearest to be: being, been, diploid, refer, occur, remain, become, produce,
# Nearest to at: mehrgarh, icann, surmised, lombards, perfecting, bidder, eastbound, kai,
# Nearest to they: we, you, he, she, asparagus, there, vitality, lawless,
# Nearest to have: has, had, having, contain, require, are, perform, include,
# Nearest to it: he, she, this, there, nothing, polos, psychometrics, ide,
# Nearest to see: but, spiritus, relativistic, volcanoes, frida, ibu, injunctions, known,
# Average loss at step 82000: 2.904672
# Average loss at step 84000: 2.831689
# Average loss at step 86000: 2.900083
# Average loss at step 88000: 2.873898
# Average loss at step 90000: 2.890565
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Nearest to these: other, different, several, certain, those, various, specific, which,
# Nearest to if: when, though, thus, then, where, because, therefore, prohibitively,
# Nearest to i: ii, we, you, g, deacidification, cantor, unbelievers, son,
# Nearest to seven: six, eight, four, five, nine, three, zero, th,
# Nearest to who: he, donny, winnipeg, constricted, aargau, rivest, postcolonial, hotspur,
# Nearest to d: b, csx, montoya, understands, dealers, writer, vpn, godless,
# Nearest to for: payments, fluctuated, lydian, sharing, impious, aulus, oxidase, auditors,
# Nearest to can: may, could, will, must, should, cannot, might, would,
# Nearest to his: her, their, my, its, your, our, s, thc,
# Nearest to be: being, been, refer, become, remain, occur, garten, diploid,
# Nearest to at: mehrgarh, icann, surmised, lombards, perfecting, allocated, bidder, lexicographic,
# Nearest to they: we, you, he, she, there, asparagus, vitality, invests,
# Nearest to have: has, had, having, contain, require, perform, cyrus, include,
# Nearest to it: he, she, this, there, nothing, ide, psychometrics, polos,
# Nearest to see: but, spiritus, relativistic, known, injunctions, ibu, solves, volcanoes,
# Average loss at step 92000: 2.879607
# Average loss at step 94000: 2.795958
# Average loss at step 96000: 2.869385
# Average loss at step 98000: 2.834027
# Average loss at step 100000: 2.608132
# Nearest to five: four, seven, three, six, eight, zero, two, nine,
# Nearest to these: certain, other, different, specific, several, various, those, whose,
# Nearest to if: when, though, thus, then, where, before, because, prohibitively,
# Nearest to i: ii, we, g, you, unbelievers, deacidification, freudian, cantor,
# Nearest to seven: eight, six, five, four, three, nine, zero, two,
# Nearest to who: winnipeg, donny, aargau, constricted, rivest, young, he, postcolonial,
# Nearest to d: b, writer, understands, dealers, montoya, globular, csx, blinding,
# Nearest to for: payments, oxidase, quoting, gentlemen, lydian, envisaged, fluctuated, nahuatl,
# Nearest to can: could, may, will, must, cannot, should, might, would,
# Nearest to his: her, their, its, my, your, our, s, the,
# Nearest to be: being, been, remain, become, occur, is, refer, diploid,
# Nearest to at: mehrgarh, surmised, icann, lombards, bidder, perfecting, maintains, near,
# Nearest to they: we, you, he, there, she, asparagus, vitality, invests,
# Nearest to have: has, had, having, contain, require, cyrus, include, are,
# Nearest to it: she, he, there, nothing, this, polos, itself, ide,
# Nearest to see: but, spiritus, relativistic, volcanoes, ibu, injunctions, frida, solves,
