# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import re
import zipfile
import bz2
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = ''


def maybe_download(url, filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename +
                        '. Can you get to it with a browser?')
    return filename


files = [
    maybe_download(
        'http://www.evanjones.ca/software/wikipedia2text-extracted.txt.bz2',
        'wikipedia_text.txt.bz2', 18377035),
    maybe_download(
            'http://mattmahoney.net/dc/text8.zip', 'text8.zip', 31344016)
]
# Out:
# Found and verified wikipedia_text.txt.bz2
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_zip_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0]))
        data = re.sub(r'[^A-Za-z0-9\s]+', '', data).lower().split()
    return data

def read_bz2_data(filename):
    with bz2.BZ2File(filename) as f:
        data = tf.compat.as_str(f.read())
        data = re.sub(r'[^A-Za-z0-9\s]+', '', data).lower().split()
    return data

def read_data(filename):
    return {
        'zip': read_zip_data,
        'bz2': read_bz2_data
    }.get(filename[-3:])(filename)

words = []
for i in range(len(files)):
    print(files[i])
    words = words + read_data(files[i])
    print('Data size %d' % len(words))
# Out:
# wikipedia_text.txt.bz2
# Data size 10098646
# text8.zip
# Data size 27103853

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000


def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary


data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 808046], ('the', 1851162), ('of', 997495), ('and', 726585), ('in', 642745)]
# Sample data [3673, 8, 6, 20267, 188, 2, 4072, 3830, 33, 12334]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0


def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels


print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(
        batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' %
          (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['propaganda', 'is', 'a', 'concerted', 'set', 'of', 'messages', 'aimed']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['is', 'is', 'a', 'a', 'concerted', 'concerted', 'set', 'set']
#     labels: ['propaganda', 'a', 'is', 'concerted', 'set', 'a', 'concerted', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'a', 'a', 'a', 'concerted', 'concerted', 'concerted', 'concerted']
#     labels: ['propaganda', 'concerted', 'set', 'is', 'set', 'of', 'is', 'a']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal(
            [vocabulary_size, embedding_size],
            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    print(embed)
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                   train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                              valid_dataset)
    similarity = tf.matmul(valid_embeddings,
                           tf.transpose(normalized_embeddings))
# Out:
# Tensor("embedding_lookup:0", shape=(128, 128), dtype=float32)

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips,
                                                  skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.358517
# Nearest to people: progesterone, syntactical, sewerage, uncontroversial, soaps, shirt, hooves, bicycle,
# Nearest to an: petrovich, river, figure, astute, mushrooms, greece, fsb, philosophies,
# Nearest to are: transactions, business, reproducing, pico, aloe, alfonso, cindy, rechargeable,
# Nearest to years: faber, carney, luce, vigorous, stacked, droplets, trope, unto,
# Nearest to these: eno, introductory, lorenzo, battle, horton, nationalism, palin, anxiety,
# Nearest to they: spears, fetishes, prolonging, honsh, redding, nineteenthcentury, anterior, radioisotopes,
# Nearest to seven: jizya, bicentennial, phnom, tm, kruger, gregory, thailand, lambs,
# Nearest to as: cetaceans, ttir, friedmans, carnot, diary, outfits, waterline, tikal,
# Nearest to to: edmontons, discharging, stretches, offering, dividing, donald, calvinism, goguryeo,
# Nearest to only: tates, muon, fausta, theory, pfizer, scythian, proven, quiet,
# Nearest to four: noncommunist, dwellings, duchy, durst, bro, osage, gannett, vesicles,
# Nearest to their: monarchy, facets, ties, esteban, pontchartrain, evasion, 151, literature,
# Nearest to world: cameroun, pinnacles, magazines, osman, falun, dmoz, videos, congratulated,
# Nearest to a: philly, magnet, presley, 1616, sequenced, ignition, disarmed, monarchs,
# Nearest to all: drifted, boyle, dividends, asphyxiation, 80, venus, familia, laughton,
# Nearest to UNK: pipes, message, unfit, outages, electrochemical, val, rez, hubbards,
# Average loss at step 2000: 4.430682
# Average loss at step 4000: 3.997399
# Average loss at step 6000: 3.833532
# Average loss at step 8000: 3.769410
# Average loss at step 10000: 3.719794
# Nearest to people: overtime, deutscher, projection, distributors, levinson, jong, exiling, pynchons,
# Nearest to an: stingray, presumably, lissitzky, boards, broadening, the, contract, forsters,
# Nearest to are: were, is, have, populous, phillies, bubble, leisurely, sect,
# Nearest to years: carney, faber, 1900, unto, drown, banners, vigorous, noble,
# Nearest to these: many, osborn, nationalism, involuntary, jaina, they, some, eno,
# Nearest to they: he, it, spears, there, nrm, fetishes, pleasure, plo,
# Nearest to seven: jizya, bicentennial, beiyang, iraq, major, spring, spassky, intercourse,
# Nearest to as: surrealism, michel, with, was, dilution, became, somalis, navratilova,
# Nearest to to: colonizing, amalric, fledgling, orogeny, tenebrae, calvinism, bias, shiloh,
# Nearest to only: shingles, even, zvi, v, imprisoning, quiet, encompassing, plexus,
# Nearest to four: liquids, ussrs, essai, osage, pathologies, perl, precision, higher,
# Nearest to their: its, his, the, monarchy, ties, bardic, foxs, gram,
# Nearest to world: city, russian, homeschooling, ancestor, manufacturers, jacobs, falun, groot,
# Nearest to a: the, one, 1616, wondrous, keaton, monarchs, omit, epitaph,
# Nearest to all: flanks, 80, henotheism, sufis, fused, infinities, drifted, die,
# Nearest to UNK: afferent, barn, hewson, highlight, novell, martov, directly, heschel,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_continuous_bag_of_batch(batch_size, window):
    global data_index
    batch = np.ndarray(shape=(batch_size, window*2), dtype=np.ndarray)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

    for i in range(batch_size):
        midpoint = data_index + window
        batch[i] = np.array(data[data_index:midpoint] + data[midpoint+1:midpoint+window+1])
        labels[i] = data[midpoint]
        data_index = (data_index + 1) % (len(data) - window * 2 - 2)
            
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:9]])

for window_size in [2, 4]:
    data_index = 0
    batch, labels = generate_continuous_bag_of_batch(20, window_size)
    print('\nwith window = %d' % (window_size))
    print('    batch:', [reverse_dictionary[bi] for bi in batch[0]])
    print('    labels:', reverse_dictionary[labels[0][0]])
# Out:
# data: ['propaganda', 'is', 'a', 'concerted', 'set', 'of', 'messages', 'aimed', 'at']
#
# with window = 2
#     batch: ['propaganda', 'is', 'concerted', 'set']
#     labels: a
#
# with window = 4
#     batch: ['propaganda', 'is', 'a', 'concerted', 'of', 'messages', 'aimed', 'at']
#     labels: set

# %%
batch_size = 128
embedding_size = 1024 # Dimension of the embedding vector.
window_size = 5
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 128 # Number of negative examples to sample.

for sample in valid_examples:
    print(reverse_dictionary[sample], end=', ')

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, window_size*2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    avg_embed =  tf.reduce_mean(embed, 1, keep_dims=False)
    # Compute the softmax loss, using a sample of the negative labels each time.
    soft_loss = tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, avg_embed, train_labels, num_sampled, vocabulary_size)
    loss = tf.reduce_mean(soft_loss)

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# both, three, first, system, called, many, these, not, state, than, no, city, he, her, most, world,

# %%
num_steps = 1000001
print_step = 10000
summary_step = 100000

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_continuous_bag_of_batch(
            batch_size, window_size)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % print_step == 0:
            if step > 0:
                average_loss = average_loss / print_step
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % summary_step == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.381725
# Nearest to both: laser, channing, grafton, attempting, corman, masculism, aggressors, sequencer,
# Nearest to three: tracking, luzon, sm, reconquered, 87, carbohydrate, retardation, small,
# Nearest to first: foe, grim, symplectic, trachea, kellogg, devices, nbc, formula,
# Nearest to system: occupancy, persisting, unseen, koala, denunciation, allafrica, gizmo, mineralogy,
# Nearest to called: magnetic, welder, autochthonous, beatrix, minnesota, walnut, hashemite, dies,
# Nearest to many: ibadi, anomalies, conceptions, emigr, cayley, immigrate, copying, emblem,
# Nearest to these: transfer, ial, verde, vitro, preservation, pls, affluent, hexagon,
# Nearest to not: argon, hilary, ventures, andean, perrin, afrikaans, plessy, simpler,
# Nearest to state: colspan, airplane, heats, geirr, serra, brecht, sarpedon, photographed,
# Nearest to than: latte, inelastic, colter, piping, 1837, listed, mccarthyism, bengali,
# Nearest to no: curries, sharpness, inductive, yielding, environmentalism, flood, vivo, bennie,
# Nearest to city: kish, galloway, 1972, omnipotent, carboxylic, unknowingly, sco, promising,
# Nearest to he: pharisees, blunted, eduard, carta, minus, neurology, recital, complement,
# Nearest to her: 03, norbert, emmett, marshland, rainbows, bao, pikemen, ciliates,
# Nearest to most: stairs, wuthering, ribbon, premium, firstborn, ferry, brummell, nationwide,
# Nearest to world: riddle, comparative, pennsylvanian, flaws, tradeoffs, pauly, lone, deposited,
# Average loss at step 10000: 4.242984
# Average loss at step 20000: 3.874119
# Average loss at step 30000: 3.849044
# Average loss at step 40000: 3.693708
# Average loss at step 50000: 3.818241
# Average loss at step 60000: 3.734101
# Average loss at step 70000: 3.685123
# Average loss at step 80000: 3.630791
# Average loss at step 90000: 3.593264
# Average loss at step 100000: 3.562465
# Nearest to both: two, corman, bbci, between, wrapping, iceberg, laser, 1666,
# Nearest to three: two, four, five, six, seven, eight, several, few,
# Nearest to first: next, foe, second, grim, tyrosine, aedile, prix, symplectic,
# Nearest to system: unseen, occupancy, systems, persisting, latinos, process, peaceful, gizmo,
# Nearest to called: known, considered, rendition, mcintyre, helmuth, welder, dostoyevsky, hashemite,
# Nearest to many: some, several, two, most, number, three, various, few,
# Nearest to these: which, they, three, whose, this, such, different, transfer,
# Nearest to not: no, never, argon, simpler, afrikaans, andean, assisted, snowflake,
# Nearest to state: government, city, serra, geirr, airplane, determinative, districts, states,
# Nearest to than: or, latte, piping, 1837, bengali, inelastic, penicillin, colter,
# Nearest to no: not, a, curries, sharpness, environmentalism, better, inductive, any,
# Nearest to city: cities, country, state, town, area, kish, galloway, province,
# Nearest to he: she, who, it, they, his, him, i, her,
# Nearest to her: his, their, him, s, its, the, he, himself,
# Nearest to most: more, many, less, stairs, sontag, largest, wuthering, vinson,
# Nearest to world: pennsylvanian, regional, international, impressed, outlaw, tradeoffs, wilderness, detonate,
# Average loss at step 110000: 3.538498
# Average loss at step 120000: 3.513994
# Average loss at step 130000: 3.505173
# Average loss at step 140000: 3.523728
# Average loss at step 150000: 3.495365
# Average loss at step 160000: 3.428341
# Average loss at step 170000: 3.512388
# Average loss at step 180000: 3.429479
# Average loss at step 190000: 3.424369
# Average loss at step 200000: 3.394944
# Nearest to both: all, between, many, bbci, iceberg, violence, establishments, wrapping,
# Nearest to three: four, five, two, six, seven, eight, several, caliber,
# Nearest to first: second, next, last, earliest, foe, tyrosine, before, ass,
# Nearest to system: systems, unseen, occupancy, process, castel, rpr, balto, persisting,
# Nearest to called: known, considered, used, referred, named, rendition, peels, autochthonous,
# Nearest to many: some, several, most, various, number, few, all, numerous,
# Nearest to these: which, they, this, such, other, different, various, whose,
# Nearest to not: never, no, nothing, cannot, simpler, argon, afrikaans, neither,
# Nearest to state: states, government, geirr, serra, colspan, bern, photons, climax,
# Nearest to than: or, piping, but, bengali, latte, 8th, 1837, like,
# Nearest to no: not, any, little, nothing, a, sharpness, stupidity, environmentalism,
# Nearest to city: town, cities, country, province, galloway, county, area, kish,
# Nearest to he: she, who, it, they, his, him, her, i,
# Nearest to her: his, their, him, its, s, my, he, she,
# Nearest to most: more, many, less, some, largest, very, highly, all,
# Nearest to world: europe, worlds, detonate, pennsylvanian, country, riddle, tradeoffs, ccd,
# Average loss at step 210000: 3.420893
# Average loss at step 220000: 3.283103
# Average loss at step 230000: 3.157426
# Average loss at step 240000: 3.231055
# Average loss at step 250000: 3.150912
# Average loss at step 260000: 3.257059
# Average loss at step 270000: 3.214001
# Average loss at step 280000: 3.214133
# Average loss at step 290000: 3.200707
# Average loss at step 300000: 3.179379
# Nearest to both: two, all, between, bbci, many, iceberg, fantasia, ethnically,
# Nearest to three: four, two, five, six, several, seven, ten, few,
# Nearest to first: second, next, last, earliest, youngest, only, reaped, tyrosine,
# Nearest to system: systems, process, unseen, network, alphabet, unit, occupancy, rpr,
# Nearest to called: known, referred, named, considered, used, rendition, termed, helmuth,
# Nearest to many: some, several, number, numerous, two, various, few, most,
# Nearest to these: which, they, such, other, various, whose, three, this,
# Nearest to not: never, no, nothing, cannot, argon, rarely, exceptionally, none,
# Nearest to state: states, government, city, country, serra, governor, national, districts,
# Nearest to than: or, piping, 8th, over, latte, like, compared, bengali,
# Nearest to no: any, not, little, nothing, never, none, inductive, a,
# Nearest to city: cities, town, country, state, province, kish, galloway, area,
# Nearest to he: she, they, it, who, his, him, i, himself,
# Nearest to her: his, their, him, its, my, the, s, she,
# Nearest to most: more, many, less, particularly, some, largest, highly, greatest,
# Nearest to world: worlds, europe, country, detonate, ccd, international, pennsylvanian, imaginary,
# Average loss at step 310000: 3.180097
# Average loss at step 320000: 3.165061
# Average loss at step 330000: 3.158299
# Average loss at step 340000: 3.164591
# Average loss at step 350000: 3.204047
# Average loss at step 360000: 3.170071
# Average loss at step 370000: 3.134044
# Average loss at step 380000: 3.203889
# Average loss at step 390000: 3.185702
# Average loss at step 400000: 3.140802
# Nearest to both: between, all, bbci, many, iceberg, wrapping, ecc, thus,
# Nearest to three: five, four, six, two, seven, several, ten, eight,
# Nearest to first: second, last, earliest, next, reaped, youngest, fourth, waxy,
# Nearest to system: systems, process, network, unit, unseen, program, occupancy, alphabet,
# Nearest to called: known, referred, named, considered, termed, used, call, spelled,
# Nearest to many: some, several, numerous, number, few, various, variety, most,
# Nearest to these: they, which, other, such, this, there, various, those,
# Nearest to not: never, no, nothing, cannot, rarely, neither, argon, unable,
# Nearest to state: states, government, serra, photons, city, bern, national, abode,
# Nearest to than: but, or, compared, piping, 8th, bengali, posit, latte,
# Nearest to no: any, nothing, little, not, none, a, inductive, never,
# Nearest to city: cities, town, country, citys, province, area, buildings, galloway,
# Nearest to he: she, it, they, who, him, his, i, her,
# Nearest to her: his, their, him, its, she, my, s, herself,
# Nearest to most: more, less, many, particularly, some, highly, fairly, biggest,
# Nearest to world: worlds, europe, country, detonate, pennsylvanian, rumor, ccd, senates,
# Average loss at step 410000: 3.125620
# Average loss at step 420000: 3.171185
# Average loss at step 430000: 3.099758
# Average loss at step 440000: 2.964843
# Average loss at step 450000: 3.037354
# Average loss at step 460000: 2.981462
# Average loss at step 470000: 3.062981
# Average loss at step 480000: 3.016467
# Average loss at step 490000: 3.017368
# Average loss at step 500000: 3.005044
# Nearest to both: all, two, between, many, bbci, suffolk, iceberg, tails,
# Nearest to three: four, two, five, six, several, seven, ten, few,
# Nearest to first: second, last, earliest, next, youngest, third, largest, fourth,
# Nearest to system: systems, program, process, model, occupancy, principle, unit, unseen,
# Nearest to called: known, referred, named, termed, considered, used, call, spelled,
# Nearest to many: some, several, numerous, number, few, various, two, variety,
# Nearest to these: they, which, such, other, whose, this, there, various,
# Nearest to not: never, nothing, no, rarely, neither, cannot, none, unable,
# Nearest to state: states, national, government, serra, city, idaho, country, enlargement,
# Nearest to than: or, compared, piping, 8th, about, like, latte, but,
# Nearest to no: any, nothing, little, not, none, a, inductive, never,
# Nearest to city: cities, town, country, citys, kish, buildings, galloway, palace,
# Nearest to he: she, they, who, it, i, his, him, galveston,
# Nearest to her: his, their, my, him, its, she, herself, s,
# Nearest to most: more, less, many, particularly, biggest, highly, greatest, worst,
# Nearest to world: worlds, europe, country, detonate, imaginary, senates, pennsylvanian, rumor,
# Average loss at step 510000: 3.002270
# Average loss at step 520000: 2.991792
# Average loss at step 530000: 2.991015
# Average loss at step 540000: 2.975004
# Average loss at step 550000: 2.992608
# Average loss at step 560000: 3.046021
# Average loss at step 570000: 3.020184
# Average loss at step 580000: 2.998848
# Average loss at step 590000: 3.030808
# Average loss at step 600000: 3.037514
# Nearest to both: all, between, many, bbci, iceberg, ethnically, suffolk, ecc,
# Nearest to three: four, five, two, six, seven, several, eight, ten,
# Nearest to first: second, last, earliest, next, youngest, longest, reaped, fourth,
# Nearest to system: systems, model, alphabet, program, process, occupancy, rpr, device,
# Nearest to called: known, referred, termed, named, considered, call, spelled, used,
# Nearest to many: several, some, numerous, number, few, various, variety, most,
# Nearest to these: which, they, other, such, various, those, this, whose,
# Nearest to not: never, nothing, no, rarely, neither, cannot, unable, t,
# Nearest to state: states, national, city, serra, abode, country, bern, photons,
# Nearest to than: compared, or, piping, like, but, unlike, latte, importantly,
# Nearest to no: nothing, any, little, not, none, inductive, plenty, never,
# Nearest to city: town, cities, citys, country, cerebellum, suburbs, cathedral, state,
# Nearest to he: she, it, they, who, his, him, asimov, i,
# Nearest to her: his, their, she, him, my, its, herself, actress,
# Nearest to most: more, less, many, fairly, biggest, highly, worst, particularly,
# Nearest to world: worlds, europe, country, detonate, america, rumor, pennsylvanian, imaginary,
# Average loss at step 610000: 3.024457
# Average loss at step 620000: 2.991290
# Average loss at step 630000: 3.017840
# Average loss at step 640000: 2.978084
# Average loss at step 650000: 2.859727
# Average loss at step 660000: 2.925262
# Average loss at step 670000: 2.864849
# Average loss at step 680000: 2.955303
# Average loss at step 690000: 2.898419
# Average loss at step 700000: 2.880966
# Nearest to both: between, all, two, bbci, many, iceberg, tails, ethnically,
# Nearest to three: two, four, five, several, six, ten, few, seven,
# Nearest to first: second, last, earliest, next, youngest, reaped, largest, third,
# Nearest to system: systems, program, alphabet, model, network, process, occupancy, method,
# Nearest to called: known, referred, termed, named, considered, spelled, call, used,
# Nearest to many: some, several, numerous, number, various, few, two, variety,
# Nearest to these: which, they, such, other, various, those, whose, freeing,
# Nearest to not: never, nothing, cannot, neither, rarely, no, unable, none,
# Nearest to state: states, country, city, idaho, serra, airplane, government, abode,
# Nearest to than: compared, or, over, like, piping, but, latte, 8th,
# Nearest to no: nothing, any, little, none, not, plenty, never, inductive,
# Nearest to city: town, cities, citys, country, suburbs, downtown, state, stadiums,
# Nearest to he: she, they, who, it, his, exemptions, him, i,
# Nearest to her: his, their, my, she, him, its, herself, your,
# Nearest to most: more, less, many, particularly, fairly, worst, biggest, largest,
# Nearest to world: worlds, europe, country, imaginary, 1900, detonate, america, disallowed,
# Average loss at step 710000: 2.892562
# Average loss at step 720000: 2.885565
# Average loss at step 730000: 2.872431
# Average loss at step 740000: 2.865716
# Average loss at step 750000: 2.868183
# Average loss at step 760000: 2.879735
# Average loss at step 770000: 2.924723
# Average loss at step 780000: 2.915176
# Average loss at step 790000: 2.907952
# Average loss at step 800000: 2.911858
# Nearest to both: between, all, many, iceberg, bbci, respectively, shaping, ethnically,
# Nearest to three: four, two, five, six, seven, ten, several, sm,
# Nearest to first: earliest, second, last, next, youngest, reaped, fourth, beginning,
# Nearest to system: systems, network, occupancy, program, unit, principle, model, castel,
# Nearest to called: known, referred, termed, named, considered, call, spelled, calling,
# Nearest to many: some, several, numerous, few, number, various, often, all,
# Nearest to these: they, which, other, such, various, there, those, this,
# Nearest to not: never, rarely, nothing, cannot, neither, no, unable, argon,
# Nearest to state: states, abode, national, serra, city, bern, photons, airplane,
# Nearest to than: compared, piping, unlike, latte, importantly, but, 8th, like,
# Nearest to no: nothing, any, little, none, plenty, not, never, inductive,
# Nearest to city: cities, town, citys, country, suburbs, cerebellum, galloway, district,
# Nearest to he: she, it, they, who, his, him, schumacher, fatherinlaw,
# Nearest to her: his, their, its, him, my, herself, she, s,
# Nearest to most: more, less, fairly, many, biggest, worst, best, extremely,
# Nearest to world: worlds, europe, country, america, 1900, imaginary, nation, pennsylvanian,
# Average loss at step 810000: 2.941267
# Average loss at step 820000: 2.934173
# Average loss at step 830000: 2.903611
# Average loss at step 840000: 2.899177
# Average loss at step 850000: 2.901533
# Average loss at step 860000: 2.783835
# Average loss at step 870000: 2.847572
# Average loss at step 880000: 2.794526
# Average loss at step 890000: 2.848954
# Average loss at step 900000: 2.829750
# Nearest to both: between, all, many, ethnically, respectively, bbci, iceberg, two,
# Nearest to three: two, four, five, several, ten, six, few, seven,
# Nearest to first: earliest, second, last, youngest, next, oldest, fourth, third,
# Nearest to system: systems, network, program, unit, principle, occupancy, platform, hotbed,
# Nearest to called: known, referred, termed, named, considered, spelled, call, used,
# Nearest to many: some, several, numerous, number, few, various, most, variety,
# Nearest to these: they, which, such, other, those, various, scotty, whose,
# Nearest to not: never, nothing, cannot, rarely, neither, unable, no, exceptionally,
# Nearest to state: states, national, country, nation, idaho, city, government, airplane,
# Nearest to than: compared, or, over, unlike, latte, distant, piping, but,
# Nearest to no: nothing, little, any, none, not, plenty, never, inductive,
# Nearest to city: town, cities, citys, country, suburbs, stadiums, area, district,
# Nearest to he: she, they, who, it, exemptions, his, fatherinlaw, him,
# Nearest to her: his, their, its, herself, my, him, she, your,
# Nearest to most: more, less, many, fairly, extremely, biggest, some, highly,
# Nearest to world: worlds, europe, country, imaginary, 1900, dacia, detonate, america,
# Average loss at step 910000: 2.779347
# Average loss at step 920000: 2.802871
# Average loss at step 930000: 2.804642
# Average loss at step 940000: 2.779560
# Average loss at step 950000: 2.777443
# Average loss at step 960000: 2.781064
# Average loss at step 970000: 2.791984
# Average loss at step 980000: 2.841719
# Average loss at step 990000: 2.831895
# Average loss at step 1000000: 2.875860
# Nearest to both: all, many, bbci, between, iceberg, sentencing, tails, shaping,
# Nearest to three: four, two, five, six, ten, several, eight, few,
# Nearest to first: earliest, second, last, youngest, next, longest, biggest, reaped,
# Nearest to system: systems, network, scheme, program, method, platform, unit, noree,
# Nearest to called: known, referred, termed, named, considered, spelled, call, calling,
# Nearest to many: several, some, numerous, number, few, most, various, variety,
# Nearest to these: they, which, other, such, there, this, various, nagumos,
# Nearest to not: never, rarely, nothing, cannot, unable, neither, no, didnt,
# Nearest to state: states, abode, serra, government, national, bern, airplane, idaho,
# Nearest to than: compared, piping, unlike, importantly, but, like, whereas, latte,
# Nearest to no: nothing, little, any, none, plenty, not, never, inductive,
# Nearest to city: town, cities, citys, cathedral, stadiums, country, suburbs, galloway,
# Nearest to he: she, it, who, they, him, his, asimov, schumacher,
# Nearest to her: his, their, herself, my, its, him, she, your,
# Nearest to most: more, less, many, biggest, fairly, worst, extremely, highly,
# Nearest to world: worlds, europe, country, worldwide, tier, 1900, america, imaginary,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
